# %% [markdown]
# -sandbox
#
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png" alt="Databricks Learning" style="width: 600px">
# </div>

# %% [markdown]
# # Exercise #2 - Batch Ingestion
#
# In this exercise you will be ingesting three batches of orders, one for 2017, 2018 and 2019.
#
# As each batch is ingested, we are going to append it to a new Delta table, unifying all the datasets into one single dataset.
#
# Each year, different individuals and different standards were used resulting in datasets that vary slightly:
# * In 2017 the backup was written as fixed-width text files
# * In 2018 the backup was written a tab-separated text files
# * In 2019 the backup was written as a "standard" comma-separted text files but the format of the column names was changed
#
# Our only goal here is to unify all the datasets while tracking the source of each record (ingested file name and ingested timestamp) should additional problems arise.
#
# Because we are only concerned with ingestion at this stage, the majority of the columns will be ingested as simple strings and in future exercises we will address this issue (and others) with various transformations.
#
# As you progress, several "reality checks" will be provided to you help ensure that you are on track - simply run the corresponding command after implementing the corresponding solution.
#
# This exercise is broken up into 3 steps:
# * Exercise 2.A - Ingest Fixed-Width File
# * Exercise 2.B - Ingest Tab-Separated File
# * Exercise 2.C - Ingest Comma-Separated File

# %% [markdown]
# <h2><img src="https://files.training.databricks.com/images/105/logo_spark_tiny.png"> Setup Exercise #2</h2>
#
# To get started, we first need to configure your Registration ID and then run the setup notebook.

# %% [markdown]
# ### Setup - Registration ID
#
# In the next commmand, please update the variable **`registration_id`** with the Registration ID you received when you signed up for this project.
#
# For more information, see [Registration ID]($./Registration ID)

# %%
# TODO
registration_id = "3339094"

# %% [markdown]
# ### Setup - Run the exercise setup
#
# Run the following cell to setup this exercise, declaring exercise-specific variables and functions.

# %%
# %run ./_includes/Setup-Exercise-02
# Out:
# <html><body><table style="width:100%">
#             <p style="font-size:16px">The following variables and functions have been defined for you.<br/>Please refer to them in the following instructions.</p><tr><th style="border-bottom:1px solid #CDCDCD; padding: 0 1em 0 0; text-align:left">Variable/Function</th>
#                  <th style="border-bottom:1px solid #CDCDCD; padding: 0 1em 0 0; text-align:left">Description</th></tr><tr><td style="font-size:16px; font-weight:bold; {padding} vertical-align:top; white-space:nowrap; color:green;">username</td>
#                  <td style="font-size:16px; font-weight:bold; {padding} vertical-align:top; white-space:nowrap; color:blue;">dakota.murdock@wavicledata.com</td>
#              </tr><tr><td style="border-bottom:1px solid #CDCDCD; font-size:16px; {padding}">&nbsp;</td>
#                  <td style="border-bottom:1px solid #CDCDCD; font-size:16px; {padding} vertical-align:top;">This is the email address that you signed into Databricks with</td></tr><tr><td style="font-size:16px; font-weight:bold; {padding} vertical-align:top; white-space:nowrap; color:green;">working_dir</td>
#                  <td style="font-size:16px; font-weight:bold; {padding} vertical-align:top; white-space:nowrap; color:blue;">dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone</td>
#              </tr><tr><td style="border-bottom:1px solid #CDCDCD; font-size:16px; {padding}">&nbsp;</td>
#                  <td style="border-bottom:1px solid #CDCDCD; font-size:16px; {padding} vertical-align:top;">This is the directory in which all work should be conducted</td></tr><tr><td style="font-size:16px; font-weight:bold; {padding} vertical-align:top; white-space:nowrap; color:green;">batch_2017_path</td>
#                  <td style="font-size:16px; font-weight:bold; {padding} vertical-align:top; white-space:nowrap; color:blue;">dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/raw/orders/batch/2017.txt</td>
#              </tr><tr><td style="border-bottom:1px solid #CDCDCD; font-size:16px; {padding}">&nbsp;</td>
#                  <td style="border-bottom:1px solid #CDCDCD; font-size:16px; {padding} vertical-align:top;">The path to the 2017 batch of orders</td></tr><tr><td style="font-size:16px; font-weight:bold; {padding} vertical-align:top; white-space:nowrap; color:green;">batch_2018_path</td>
#                  <td style="font-size:16px; font-weight:bold; {padding} vertical-align:top; white-space:nowrap; color:blue;">dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/raw/orders/batch/2018.csv</td>
#              </tr><tr><td style="border-bottom:1px solid #CDCDCD; font-size:16px; {padding}">&nbsp;</td>
#                  <td style="border-bottom:1px solid #CDCDCD; font-size:16px; {padding} vertical-align:top;">The path to the 2018 batch of orders</td></tr><tr><td style="font-size:16px; font-weight:bold; {padding} vertical-align:top; white-space:nowrap; color:green;">batch_2019_path</td>
#                  <td style="font-size:16px; font-weight:bold; {padding} vertical-align:top; white-space:nowrap; color:blue;">dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/raw/orders/batch/2019.csv</td>
#              </tr><tr><td style="border-bottom:1px solid #CDCDCD; font-size:16px; {padding}">&nbsp;</td>
#                  <td style="border-bottom:1px solid #CDCDCD; font-size:16px; {padding} vertical-align:top;">The path to the 2019 batch of orders</td></tr><tr><td style="font-size:16px; font-weight:bold; {padding} vertical-align:top; white-space:nowrap; color:green;">batch_target_path</td>
#                  <td style="font-size:16px; font-weight:bold; {padding} vertical-align:top; white-space:nowrap; color:blue;">dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta</td>
#              </tr><tr><td style="border-bottom:1px solid #CDCDCD; font-size:16px; {padding}">&nbsp;</td>
#                  <td style="border-bottom:1px solid #CDCDCD; font-size:16px; {padding} vertical-align:top;">The location of the new, unified, raw, batch of orders & sales reps</td></tr><tr><td style="border-bottom:1px solid #CDCDCD;; font-size:16px; {padding} vertical-align:top; font-weight:bold; white-space:nowrap; color:green;">reality_check_02_a()</td>
#                  <td style="border-bottom:1px solid #CDCDCD;; font-size:16px; {padding} vertical-align:top;">A utility function for validating Exercise #2.A</td></td></tr><tr><td style="border-bottom:1px solid #CDCDCD;; font-size:16px; {padding} vertical-align:top; font-weight:bold; white-space:nowrap; color:green;">reality_check_02_b()</td>
#                  <td style="border-bottom:1px solid #CDCDCD;; font-size:16px; {padding} vertical-align:top;">A utility function for validating Exercise #2.B</td></td></tr><tr><td style="border-bottom:1px solid #CDCDCD;; font-size:16px; {padding} vertical-align:top; font-weight:bold; white-space:nowrap; color:green;">reality_check_02_c()</td>
#                  <td style="border-bottom:1px solid #CDCDCD;; font-size:16px; {padding} vertical-align:top;">A utility function for validating Exercise #2.C</td></td></tr><tr><td style="border-bottom:1px solid #CDCDCD;; font-size:16px; {padding} vertical-align:top; font-weight:bold; white-space:nowrap; color:green;">reality_check_02_final()</td>
#                  <td style="border-bottom:1px solid #CDCDCD;; font-size:16px; {padding} vertical-align:top;">A utility function for validating the entire exercise</td></td></tr></table></body></html>

# %% [markdown]
# Run the following cell to preview a list of the files you will be processing in this exercise.

# %%
files = dbutils.fs.ls(f"{working_dir}/raw/orders/batch") # List all the files
display(files)                                           # Display the list of files
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/raw/orders/batch/2017.txt</td><td>2017.txt</td><td>160422092</td></tr><tr><td>dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/raw/orders/batch/2018.csv</td><td>2018.csv</td><td>110777063</td></tr><tr><td>dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/raw/orders/batch/2019.csv</td><td>2019.csv</td><td>125058494</td></tr></tbody></table></div>

# %% [markdown]
# <h2><img src="https://files.training.databricks.com/images/105/logo_spark_tiny.png"> Exercise #2.A - Ingest Fixed-Width File</h2>
#
# **In this step you will need to:**
# 1. Use the variable **`batch_2017_path`**, and **`dbutils.fs.head`** to investigate the 2017 batch file, if needed.
# 2. Configure a **`DataFrameReader`** to ingest the text file identified by **`batch_2017_path`** - this should provide one record per line, with a single column named **`value`**
# 3. Using the information in **`fixed_width_column_defs`** (or the dictionary itself) use the **`value`** column to extract each new column of the appropriate length.<br/>
#   * The dictionary's key is the column name
#   * The first element in the dictionary's value is the starting position of that column's data
#   * The second element in the dictionary's value is the length of that column's data
# 4. Once you are done with the **`value`** column, remove it.
# 5. For each new column created in step #3, remove any leading whitespace
#   * The introduction of \[leading\] white space should be expected when extracting fixed-width values out of the **`value`** column.
# 6. For each new column created in step #3, replace all empty strings with **`null`**.
#   * After trimming white space, any column for which a value was not specified in the original dataset should result in an empty string.
# 7. Add a new column, **`ingest_file_name`**, which is the name of the file from which the data was read from.
#   * This should not be hard coded.
#   * For the proper function, see the <a href="https://spark.apache.org/docs/latest/api/python/index.html" target="_blank">pyspark.sql.functions</a> module
# 8. Add a new column, **`ingested_at`**, which is a timestamp of when the data was ingested as a DataFrame.
#   * This should not be hard coded.
#   * For the proper function, see the <a href="https://spark.apache.org/docs/latest/api/python/index.html" target="_blank">pyspark.sql.functions</a> module
# 9. Write the corresponding **`DataFrame`** in the "delta" format to the location specified by **`batch_target_path`**
#
# **Special Notes:**
# * It is possible to use the dictionary **`fixed_width_column_defs`** and programatically extract <br/>
#   each column but, it is also perfectly OK to hard code this step and extract one column at a time.
# * The **`SparkSession`** is already provided to you as an instance of **`spark`**.
# * The classes/methods that you will need for this exercise include:
#   * **`pyspark.sql.DataFrameReader`** to ingest data
#   * **`pyspark.sql.DataFrameWriter`** to ingest data
#   * **`pyspark.sql.Column`** to transform data
#   * Various functions from the **`pyspark.sql.functions`** module
#   * Various transformations and actions from **`pyspark.sql.DataFrame`**
# * The following methods can be used to investigate and manipulate the Databricks File System (DBFS)
#   * **`dbutils.fs.ls(..)`** for listing files
#   * **`dbutils.fs.rm(..)`** for removing files
#   * **`dbutils.fs.head(..)`** to view the first N bytes of a file
#
# **Additional Requirements:**
# * The unified batch dataset must be written to disk in the "delta" format
# * The schema for the unified batch dataset must be:
#   * **`submitted_at`**:**`string`**
#   * **`order_id`**:**`string`**
#   * **`customer_id`**:**`string`**
#   * **`sales_rep_id`**:**`string`**
#   * **`sales_rep_ssn`**:**`string`**
#   * **`sales_rep_first_name`**:**`string`**
#   * **`sales_rep_last_name`**:**`string`**
#   * **`sales_rep_address`**:**`string`**
#   * **`sales_rep_city`**:**`string`**
#   * **`sales_rep_state`**:**`string`**
#   * **`sales_rep_zip`**:**`string`**
#   * **`shipping_address_attention`**:**`string`**
#   * **`shipping_address_address`**:**`string`**
#   * **`shipping_address_city`**:**`string`**
#   * **`shipping_address_state`**:**`string`**
#   * **`shipping_address_zip`**:**`string`**
#   * **`product_id`**:**`string`**
#   * **`product_quantity`**:**`string`**
#   * **`product_sold_price`**:**`string`**
#   * **`ingest_file_name`**:**`string`**
#   * **`ingested_at`**:**`timestamp`**

# %% [markdown]
# ### Fixed-Width Meta Data
#
# The following dictionary is provided for reference and/or implementation<br/>
# (depending on which strategy you choose to employ).
#
# Run the following cell to instantiate it.

# %%
fixed_width_column_defs = {
  "submitted_at": (1, 15),
  "order_id": (16, 40),
  "customer_id": (56, 40),
  "sales_rep_id": (96, 40),
  "sales_rep_ssn": (136, 15),
  "sales_rep_first_name": (151, 15),
  "sales_rep_last_name": (166, 15),
  "sales_rep_address": (181, 40),
  "sales_rep_city": (221, 20),
  "sales_rep_state": (241, 2),
  "sales_rep_zip": (243, 5),
  "shipping_address_attention": (248, 30),
  "shipping_address_address": (278, 40),
  "shipping_address_city": (318, 20),
  "shipping_address_state": (338, 2),
  "shipping_address_zip": (340, 5),
  "product_id": (345, 40),
  "product_quantity": (385, 5),
  "product_sold_price": (390, 20)
}

# %% [markdown]
# ### Implement Exercise #2.A
#
# Implement your solution in the following cell:

# %%
dbutils.fs.ls(batch_target_path)
# Out:
# Out[15]: [FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/_delta_log/', name='_delta_log/', size=0),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00000-01c9595e-b2a3-4cdc-81c0-2d61fec61873-c000.snappy.parquet', name='part-00000-01c9595e-b2a3-4cdc-81c0-2d61fec61873-c000.snappy.parquet', size=1141902),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00000-05c02f90-154b-4f55-aaf1-7d1526f67df6-c000.snappy.parquet', name='part-00000-05c02f90-154b-4f55-aaf1-7d1526f67df6-c000.snappy.parquet', size=1141902),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00000-3a04c528-621d-4171-8710-b375fd6f22dc-c000.snappy.parquet', name='part-00000-3a04c528-621d-4171-8710-b375fd6f22dc-c000.snappy.parquet', size=1133423),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00000-51e1bfd9-7720-437b-b54c-e2219fdf0bae-c000.snappy.parquet', name='part-00000-51e1bfd9-7720-437b-b54c-e2219fdf0bae-c000.snappy.parquet', size=1141902),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00000-6846d2ab-300e-482a-ac74-311f6452a249-c000.snappy.parquet', name='part-00000-6846d2ab-300e-482a-ac74-311f6452a249-c000.snappy.parquet', size=1148755),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00000-74784184-d935-4432-94ea-8728e61bd966-c000.snappy.parquet', name='part-00000-74784184-d935-4432-94ea-8728e61bd966-c000.snappy.parquet', size=1148755),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00000-91de7dbc-a742-41f4-b643-05958a87c736-c000.snappy.parquet', name='part-00000-91de7dbc-a742-41f4-b643-05958a87c736-c000.snappy.parquet', size=1148755),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00000-9478417e-1e67-4da5-8096-98375298909d-c000.snappy.parquet', name='part-00000-9478417e-1e67-4da5-8096-98375298909d-c000.snappy.parquet', size=1141902),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00000-bf9f9fa9-8f56-4163-b1ce-c7d6a2545925-c000.snappy.parquet', name='part-00000-bf9f9fa9-8f56-4163-b1ce-c7d6a2545925-c000.snappy.parquet', size=1133423),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00000-d5402e73-64be-4226-9520-edeab4bc35b3-c000.snappy.parquet', name='part-00000-d5402e73-64be-4226-9520-edeab4bc35b3-c000.snappy.parquet', size=1141902),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00000-d6bf37b1-a264-4822-ae0a-aa66ffc267af-c000.snappy.parquet', name='part-00000-d6bf37b1-a264-4822-ae0a-aa66ffc267af-c000.snappy.parquet', size=1133423),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00001-0852a910-7781-4dee-8700-11caa9ca5422-c000.snappy.parquet', name='part-00001-0852a910-7781-4dee-8700-11caa9ca5422-c000.snappy.parquet', size=1142310),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00001-3ab41afe-af99-46b0-9bad-60c8bda52e14-c000.snappy.parquet', name='part-00001-3ab41afe-af99-46b0-9bad-60c8bda52e14-c000.snappy.parquet', size=1137814),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00001-5ad9dc47-d0ec-44f4-af56-0396d40b5725-c000.snappy.parquet', name='part-00001-5ad9dc47-d0ec-44f4-af56-0396d40b5725-c000.snappy.parquet', size=1142310),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00001-5e1c3c1b-1598-4b46-9a88-772564fd61ab-c000.snappy.parquet', name='part-00001-5e1c3c1b-1598-4b46-9a88-772564fd61ab-c000.snappy.parquet', size=1137814),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00001-6adcab39-47c1-4253-a6dd-10c4325d997e-c000.snappy.parquet', name='part-00001-6adcab39-47c1-4253-a6dd-10c4325d997e-c000.snappy.parquet', size=1141067),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00001-6d28bcf6-84ce-4b15-b16d-2b655154ea53-c000.snappy.parquet', name='part-00001-6d28bcf6-84ce-4b15-b16d-2b655154ea53-c000.snappy.parquet', size=1137814),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00001-72a6a111-cc4e-4d97-a1fc-5b61b3ba47e2-c000.snappy.parquet', name='part-00001-72a6a111-cc4e-4d97-a1fc-5b61b3ba47e2-c000.snappy.parquet', size=1137814),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00001-7fd8a390-6d43-44a4-88be-3639d52bd2ca-c000.snappy.parquet', name='part-00001-7fd8a390-6d43-44a4-88be-3639d52bd2ca-c000.snappy.parquet', size=1137814),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00001-b09ca1f7-9bac-4a6a-9db5-cecaf797c528-c000.snappy.parquet', name='part-00001-b09ca1f7-9bac-4a6a-9db5-cecaf797c528-c000.snappy.parquet', size=1142310),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00001-f2ef641e-ad1b-41ce-9335-72488d3a4fa6-c000.snappy.parquet', name='part-00001-f2ef641e-ad1b-41ce-9335-72488d3a4fa6-c000.snappy.parquet', size=1141067),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00001-f82443ec-3d98-4d65-9cb5-89bc132a485f-c000.snappy.parquet', name='part-00001-f82443ec-3d98-4d65-9cb5-89bc132a485f-c000.snappy.parquet', size=1141067),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00002-1ec4879c-0a24-4705-8af9-a4af02200b43-c000.snappy.parquet', name='part-00002-1ec4879c-0a24-4705-8af9-a4af02200b43-c000.snappy.parquet', size=1152871),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00002-20b136b5-29f0-4fda-ac64-3b43fe1ba44b-c000.snappy.parquet', name='part-00002-20b136b5-29f0-4fda-ac64-3b43fe1ba44b-c000.snappy.parquet', size=1151985),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00002-307779e5-22f0-4bb6-b957-8bc1c4fc4174-c000.snappy.parquet', name='part-00002-307779e5-22f0-4bb6-b957-8bc1c4fc4174-c000.snappy.parquet', size=1151985),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00002-312144a5-9cb7-4dd3-b4ff-b40d569de397-c000.snappy.parquet', name='part-00002-312144a5-9cb7-4dd3-b4ff-b40d569de397-c000.snappy.parquet', size=1152871),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00002-454b19df-07eb-4625-9e4c-1ea7fdf098c9-c000.snappy.parquet', name='part-00002-454b19df-07eb-4625-9e4c-1ea7fdf098c9-c000.snappy.parquet', size=1136476),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00002-47f1f420-500b-41b4-bb47-dc6cf17c5b7e-c000.snappy.parquet', name='part-00002-47f1f420-500b-41b4-bb47-dc6cf17c5b7e-c000.snappy.parquet', size=1136476),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00002-6e64e027-62a2-427d-97e2-940186adf348-c000.snappy.parquet', name='part-00002-6e64e027-62a2-427d-97e2-940186adf348-c000.snappy.parquet', size=1136476),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00002-a9bb8302-4e2e-43ff-8624-2689e2bfabeb-c000.snappy.parquet', name='part-00002-a9bb8302-4e2e-43ff-8624-2689e2bfabeb-c000.snappy.parquet', size=1136476),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00002-c0c5c0cb-6bf0-4a53-8046-2fdbb24ecce0-c000.snappy.parquet', name='part-00002-c0c5c0cb-6bf0-4a53-8046-2fdbb24ecce0-c000.snappy.parquet', size=1136476),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00002-dc098ff7-499f-49a5-8662-3648f4cb8611-c000.snappy.parquet', name='part-00002-dc098ff7-499f-49a5-8662-3648f4cb8611-c000.snappy.parquet', size=1152871),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00002-fa6c9f26-61fb-4eb6-bf2b-f0dd2f348f82-c000.snappy.parquet', name='part-00002-fa6c9f26-61fb-4eb6-bf2b-f0dd2f348f82-c000.snappy.parquet', size=1151985),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00003-00b28111-4e61-4812-90aa-dd613a299180-c000.snappy.parquet', name='part-00003-00b28111-4e61-4812-90aa-dd613a299180-c000.snappy.parquet', size=1150206),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00003-1d582b5c-3c5e-44c9-9853-3039a9cd0ad4-c000.snappy.parquet', name='part-00003-1d582b5c-3c5e-44c9-9853-3039a9cd0ad4-c000.snappy.parquet', size=1150206),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00003-4fe4a88c-40bb-4e95-b153-dbba13c027f4-c000.snappy.parquet', name='part-00003-4fe4a88c-40bb-4e95-b153-dbba13c027f4-c000.snappy.parquet', size=1126035),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00003-54456577-d1cd-47f0-ab46-78e3f33aad11-c000.snappy.parquet', name='part-00003-54456577-d1cd-47f0-ab46-78e3f33aad11-c000.snappy.parquet', size=1126035),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00003-7cfdd609-f4ec-4ae8-9795-ac4ec4eb045f-c000.snappy.parquet', name='part-00003-7cfdd609-f4ec-4ae8-9795-ac4ec4eb045f-c000.snappy.parquet', size=1146415),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00003-8c796f09-5a72-4b13-8e58-dce2f134e078-c000.snappy.parquet', name='part-00003-8c796f09-5a72-4b13-8e58-dce2f134e078-c000.snappy.parquet', size=1150206),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00003-c5b33386-8159-4427-8f9f-4f55b8fcf901-c000.snappy.parquet', name='part-00003-c5b33386-8159-4427-8f9f-4f55b8fcf901-c000.snappy.parquet', size=1126035),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00003-d4e9c13b-2cc2-4ad1-82f6-342539b6a345-c000.snappy.parquet', name='part-00003-d4e9c13b-2cc2-4ad1-82f6-342539b6a345-c000.snappy.parquet', size=1146415),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00003-e31e5e51-e400-41d4-9083-59a76f034aea-c000.snappy.parquet', name='part-00003-e31e5e51-e400-41d4-9083-59a76f034aea-c000.snappy.parquet', size=1126035),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00003-e9ad9977-a07c-47ee-a5a7-3f982d4931e5-c000.snappy.parquet', name='part-00003-e9ad9977-a07c-47ee-a5a7-3f982d4931e5-c000.snappy.parquet', size=1126035),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00003-ee7004c6-51df-4f4e-a88d-762069fd8f5b-c000.snappy.parquet', name='part-00003-ee7004c6-51df-4f4e-a88d-762069fd8f5b-c000.snappy.parquet', size=1146415),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00004-04b652dc-e43d-476b-88bb-983b19eefd8b-c000.snappy.parquet', name='part-00004-04b652dc-e43d-476b-88bb-983b19eefd8b-c000.snappy.parquet', size=1143697),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00004-17ca07f5-fb14-4107-9e63-f88c5a7ed52a-c000.snappy.parquet', name='part-00004-17ca07f5-fb14-4107-9e63-f88c5a7ed52a-c000.snappy.parquet', size=1143697),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00004-1b20103a-9618-4c4e-b76e-9ea0b5ddd9f4-c000.snappy.parquet', name='part-00004-1b20103a-9618-4c4e-b76e-9ea0b5ddd9f4-c000.snappy.parquet', size=1131667),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00004-23681066-76fb-40b3-9d1b-b41df60707f3-c000.snappy.parquet', name='part-00004-23681066-76fb-40b3-9d1b-b41df60707f3-c000.snappy.parquet', size=1152433),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00004-25d35ef1-f21a-49a5-b21f-cd9f2d774b42-c000.snappy.parquet', name='part-00004-25d35ef1-f21a-49a5-b21f-cd9f2d774b42-c000.snappy.parquet', size=1131667),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00004-2fa44dfa-2363-4471-bc1d-8506f2d63c9a-c000.snappy.parquet', name='part-00004-2fa44dfa-2363-4471-bc1d-8506f2d63c9a-c000.snappy.parquet', size=1143697),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00004-3bf4a1b8-c80f-4818-8839-127d0c250b96-c000.snappy.parquet', name='part-00004-3bf4a1b8-c80f-4818-8839-127d0c250b96-c000.snappy.parquet', size=1152433),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00004-5ebdea8d-d139-405e-9e7a-f7daf37961fa-c000.snappy.parquet', name='part-00004-5ebdea8d-d139-405e-9e7a-f7daf37961fa-c000.snappy.parquet', size=1131667),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00004-5ffc3bae-b696-4917-9024-2a7cf813067b-c000.snappy.parquet', name='part-00004-5ffc3bae-b696-4917-9024-2a7cf813067b-c000.snappy.parquet', size=1131667),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00004-9b7e603e-2ebe-41bc-8314-7514921ab6fe-c000.snappy.parquet', name='part-00004-9b7e603e-2ebe-41bc-8314-7514921ab6fe-c000.snappy.parquet', size=1131667),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00004-ec47402b-2876-47b0-8b6d-74448c8735cb-c000.snappy.parquet', name='part-00004-ec47402b-2876-47b0-8b6d-74448c8735cb-c000.snappy.parquet', size=1152433),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00005-0ecadbb3-bb7b-4e8c-8149-a44b795ad39e-c000.snappy.parquet', name='part-00005-0ecadbb3-bb7b-4e8c-8149-a44b795ad39e-c000.snappy.parquet', size=1154253),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00005-1aa827ca-f2ab-47ed-98cf-0a4b102aa440-c000.snappy.parquet', name='part-00005-1aa827ca-f2ab-47ed-98cf-0a4b102aa440-c000.snappy.parquet', size=1146765),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00005-235f648f-8f94-4756-9f49-fe51b6fbfb97-c000.snappy.parquet', name='part-00005-235f648f-8f94-4756-9f49-fe51b6fbfb97-c000.snappy.parquet', size=1154253),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00005-2ff6b4c7-46ca-4f5f-b473-5922721fcf97-c000.snappy.parquet', name='part-00005-2ff6b4c7-46ca-4f5f-b473-5922721fcf97-c000.snappy.parquet', size=1137164),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00005-345da446-7063-47d3-9f77-cc8207012106-c000.snappy.parquet', name='part-00005-345da446-7063-47d3-9f77-cc8207012106-c000.snappy.parquet', size=1137164),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00005-4c506394-c6f8-43c8-a827-68ba74de9b74-c000.snappy.parquet', name='part-00005-4c506394-c6f8-43c8-a827-68ba74de9b74-c000.snappy.parquet', size=1146765),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00005-54da4e79-5447-4197-a532-7d5d7e97ab94-c000.snappy.parquet', name='part-00005-54da4e79-5447-4197-a532-7d5d7e97ab94-c000.snappy.parquet', size=1146765),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00005-5d55fc3f-b8d7-4991-add2-a7d8e27b3527-c000.snappy.parquet', name='part-00005-5d55fc3f-b8d7-4991-add2-a7d8e27b3527-c000.snappy.parquet', size=1137164),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00005-addc69c9-7053-4233-a20b-ce90cc908950-c000.snappy.parquet', name='part-00005-addc69c9-7053-4233-a20b-ce90cc908950-c000.snappy.parquet', size=1137164),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00005-c30bcc54-5148-4137-9837-f3ed2ac6c6e6-c000.snappy.parquet', name='part-00005-c30bcc54-5148-4137-9837-f3ed2ac6c6e6-c000.snappy.parquet', size=1154253),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00005-dcfc94bd-e394-4a4f-9d09-b6bad801ae78-c000.snappy.parquet', name='part-00005-dcfc94bd-e394-4a4f-9d09-b6bad801ae78-c000.snappy.parquet', size=1137164),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00006-07a111c0-81ca-4fa8-8ef9-1015ff2e6a64-c000.snappy.parquet', name='part-00006-07a111c0-81ca-4fa8-8ef9-1015ff2e6a64-c000.snappy.parquet', size=1137740),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00006-18c8bf58-8acc-49a2-82a9-4b29c2d92cf5-c000.snappy.parquet', name='part-00006-18c8bf58-8acc-49a2-82a9-4b29c2d92cf5-c000.snappy.parquet', size=1137740),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00006-1df799d9-e7fe-4f40-a0d2-0a8887df6679-c000.snappy.parquet', name='part-00006-1df799d9-e7fe-4f40-a0d2-0a8887df6679-c000.snappy.parquet', size=1136702),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00006-1fb798fa-e56c-4d46-a51c-7f012b828e1b-c000.snappy.parquet', name='part-00006-1fb798fa-e56c-4d46-a51c-7f012b828e1b-c000.snappy.parquet', size=1136702),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00006-68ceb678-a36d-48fc-88a5-351244426d94-c000.snappy.parquet', name='part-00006-68ceb678-a36d-48fc-88a5-351244426d94-c000.snappy.parquet', size=1159387),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00006-a167c0de-5ffe-49e8-bcb3-01f65d4b97a9-c000.snappy.parquet', name='part-00006-a167c0de-5ffe-49e8-bcb3-01f65d4b97a9-c000.snappy.parquet', size=1137740),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00006-a84eeaee-fd6e-47dc-80e7-9cfd85aeb596-c000.snappy.parquet', name='part-00006-a84eeaee-fd6e-47dc-80e7-9cfd85aeb596-c000.snappy.parquet', size=1136702),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00006-afd86139-98a8-4514-9546-be7a3163638b-c000.snappy.parquet', name='part-00006-afd86139-98a8-4514-9546-be7a3163638b-c000.snappy.parquet', size=1136702),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00006-c2e79d03-b607-432a-81a2-b14012f5b22e-c000.snappy.parquet', name='part-00006-c2e79d03-b607-432a-81a2-b14012f5b22e-c000.snappy.parquet', size=1159387),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00006-c60f33f5-c5b4-4169-8b0e-d8154a947bda-c000.snappy.parquet', name='part-00006-c60f33f5-c5b4-4169-8b0e-d8154a947bda-c000.snappy.parquet', size=1159387),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00006-e3177515-4882-4c8c-89e4-b13a2cd3dd03-c000.snappy.parquet', name='part-00006-e3177515-4882-4c8c-89e4-b13a2cd3dd03-c000.snappy.parquet', size=1136702),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00007-157cae3e-fc7d-4af3-8d8c-29616a008ba6-c000.snappy.parquet', name='part-00007-157cae3e-fc7d-4af3-8d8c-29616a008ba6-c000.snappy.parquet', size=890023),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00007-29eba650-b2f8-4780-b63a-ed3aa5e43813-c000.snappy.parquet', name='part-00007-29eba650-b2f8-4780-b63a-ed3aa5e43813-c000.snappy.parquet', size=934290),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00007-332c661d-4d39-464c-9439-bdf8ec0aa30b-c000.snappy.parquet', name='part-00007-332c661d-4d39-464c-9439-bdf8ec0aa30b-c000.snappy.parquet', size=868687),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00007-3e03680a-5120-4961-a774-cff0cefabf0d-c000.snappy.parquet', name='part-00007-3e03680a-5120-4961-a774-cff0cefabf0d-c000.snappy.parquet', size=868687),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00007-6fb66d6a-bf30-460b-afe1-0b8cffcaab1d-c000.snappy.parquet', name='part-00007-6fb66d6a-bf30-460b-afe1-0b8cffcaab1d-c000.snappy.parquet', size=934290),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00007-77ff6f4a-ee20-4a11-a6f9-c9815d7e80d8-c000.snappy.parquet', name='part-00007-77ff6f4a-ee20-4a11-a6f9-c9815d7e80d8-c000.snappy.parquet', size=890023),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00007-85b60a8b-a006-4536-a931-72e6f8bbb6d1-c000.snappy.parquet', name='part-00007-85b60a8b-a006-4536-a931-72e6f8bbb6d1-c000.snappy.parquet', size=934290),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00007-c9987ac9-6ddd-4d0a-9c84-e58b89ad1ca1-c000.snappy.parquet', name='part-00007-c9987ac9-6ddd-4d0a-9c84-e58b89ad1ca1-c000.snappy.parquet', size=868687),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00007-e04866b6-3f11-42eb-a1cd-5bf2447b89b0-c000.snappy.parquet', name='part-00007-e04866b6-3f11-42eb-a1cd-5bf2447b89b0-c000.snappy.parquet', size=890023),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00007-eb48d8d6-9d18-4efe-878a-203bcec4f986-c000.snappy.parquet', name='part-00007-eb48d8d6-9d18-4efe-878a-203bcec4f986-c000.snappy.parquet', size=934290),
#  FileInfo(path='dbfs:/user/dakota.murdock@wavicledata.com/dbacademy/developer-foundations-capstone/batch_orders_dirty.delta/part-00007-efa4f34f-f554-4268-b169-c78f21cdf292-c000.snappy.parquet', name='part-00007-efa4f34f-f554-4268-b169-c78f21cdf292-c000.snappy.parquet', size=934290)]

# %%
# dbutils.fs.head(batch_2017_path)
from pyspark.sql.functions import *

# Read in 2017 file into dataframe
df_2017 = spark.read.format('text').load(batch_2017_path)

# Creating a list to store strings of commands to be generated in loop
schema_list = []
# Looping through provided dictionary to create string commands that will be used to convert fixed width data into separate columns
for key in fixed_width_column_defs:
    pos = fixed_width_column_defs.get(key)
    schema_list.append(f"ltrim(df_2017.value.substr({pos[0]}, {pos[1]})).alias(\"{key}\")")

# Creating a single string from the list of string commands generated in the loop 
schema_string = ", ".join(schema_list)

# Programatically converting the fixed with 'value' column into separate columns utilizing previously created string of fixed width information
exec(f"""df_2017_columns = (df_2017.select({schema_string}))""")

# Performing transformations to dataframe
df_2017_columns = df_2017_columns.na.replace('', None) # Fill empty strings with null
df_2017_columns = df_2017_columns.withColumn("ingest_file_name", input_file_name()).withColumn("ingested_at", current_timestamp()) # Add columns containing the source file name and the time it was ingested at

# Write the dataframe to delta table
df_2017_columns.write.format("delta").mode("overwrite").save(batch_target_path)

# %% [markdown]
# ### Reality Check #2.A
# Run the following command to ensure that you are on track:

# %%
reality_check_02_a()
# Out:
# PYTHON ERROR Invalid argument, not a string or column: 1636990662483.615 of type <class 'float'>. For column literals, use 'lit', 'array', 'struct' or 'create_map' function.
# PYTHON ERROR Invalid argument, not a string or column: 1636990662510.216 of type <class 'float'>. For column literals, use 'lit', 'array', 'struct' or 'create_map' function.
# PYTHON ERROR Invalid argument, not a string or column: 1636990662792.8596 of type <class 'float'>. For column literals, use 'lit', 'array', 'struct' or 'create_map' function.
# PYTHON ERROR Invalid argument, not a string or column: 1636990663025.7673 of type <class 'float'>. For column literals, use 'lit', 'array', 'struct' or 'create_map' function.
# PYTHON ERROR Invalid argument, not a string or column: 1636990663251.448 of type <class 'float'>. For column literals, use 'lit', 'array', 'struct' or 'create_map' function.
# PYTHON ERROR Invalid argument, not a string or column: 1636990663435.6226 of type <class 'float'>. For column literals, use 'lit', 'array', 'struct' or 'create_map' function.
# PYTHON ERROR Invalid argument, not a string or column: 1636990667660.0374 of type <class 'float'>. For column literals, use 'lit', 'array', 'struct' or 'create_map' function.
# PYTHON ERROR Invalid argument, not a string or column: 1636990699415.453 of type <class 'float'>. For column literals, use 'lit', 'array', 'struct' or 'create_map' function.
# PYTHON ERROR Invalid argument, not a string or column: 1636990726315.872 of type <class 'float'>. For column literals, use 'lit', 'array', 'struct' or 'create_map' function.
# PYTHON ERROR Invalid argument, not a string or column: 1636990752502.4917 of type <class 'float'>. For column literals, use 'lit', 'array', 'struct' or 'create_map' function.
# PYTHON ERROR Invalid argument, not a string or column: 1636990756450.725 of type <class 'float'>. For column literals, use 'lit', 'array', 'struct' or 'create_map' function.
# PYTHON ERROR Invalid argument, not a string or column: 1636990758600.876 of type <class 'float'>. For column literals, use 'lit', 'array', 'struct' or 'create_map' function.
# PYTHON ERROR Invalid argument, not a string or column: 1636990771085.2478 of type <class 'float'>. For column literals, use 'lit', 'array', 'struct' or 'create_map' function.
# PYTHON ERROR Invalid argument, not a string or column: 1636990771132.9417 of type <class 'float'>. For column literals, use 'lit', 'array', 'struct' or 'create_map' function.
# <style>
#   table { text-align: left; border-collapse: collapse; margin: 1em; caption-side: bottom; font-family: Sans-Serif; font-size: 16px}
#   caption { text-align: left; padding: 5px }
#   th, td { border: 1px solid #ddd; padding: 5px }
#   th { background-color: #ddd }
#   .passed { background-color: #97d897 }
#   .failed { background-color: #e2716c }
#   .skipped { background-color: #f9d275 }
#   .results .points { display: none }
#   .results .message { display: block; font-size:smaller; color:gray }
#   .results .note { display: block; font-size:smaller; font-decoration:italics }
#   .results .passed::before  { content: "Passed" }
#   .results .failed::before  { content: "Failed" }
#   .results .skipped::before { content: "Skipped" }
#   .grade .passed  .message:empty::before { content:"Passed" }
#   .grade .failed  .message:empty::before { content:"Failed" }
#   .grade .skipped .message:empty::before { content:"Skipped" }
# </style>
# <table class='results'>
#   <tr><th class='points'>Points</th><th class='test'>Test</th><th class='result'>Result</th></tr>
# <tr>
#   <td class='points'>1</td>
#   <td class='test'>
#     Using DBR 9.1 & Proper Cluster Configuration
#   </td>
#   <td class='result passed'></td>
# </tr>
# <tr>
#   <td class='points'>1</td>
#   <td class='test'>
#     Valid Registration ID
#   </td>
#   <td class='result passed'></td>
# </tr>
# <tr>
#   <td class='points'>1</td>
#   <td class='test'>
#     Target directory exists
#   </td>
#   <td class='result passed'></td>
# </tr>
# <tr>
#   <td class='points'>1</td>
#   <td class='test'>
#     Using the Delta file format
#   </td>
#   <td class='result passed'></td>
# </tr>
# <tr>
#   <td class='points'>1</td>
#   <td class='test'>
#     Found at least one Parquet part-file
#   </td>
#   <td class='result passed'></td>
# </tr>
# <tr>
#   <td class='points'>1</td>
#   <td class='test'>
#     Schema is valid
#   </td>
#   <td class='result passed'></td>
# </tr>
# <tr>
#   <td class='points'>1</td>
#   <td class='test'>
#     Expected 391,266 records
#   </td>
#   <td class='result passed'></td>
# </tr>
# <tr>
#   <td class='points'>1</td>
#   <td class='test'>
#     No leading or trailing whitespace in column values, need to trim
#   </td>
#   <td class='result passed'></td>
# </tr>
# <tr>
#   <td class='points'>1</td>
#   <td class='test'>
#     No empty strings in column values, should be the SQL value null
#   </td>
#   <td class='result passed'></td>
# </tr>
# <tr>
#   <td class='points'>1</td>
#   <td class='test'>
#     No "null" strings for column values, should be the SQL value null
#   </td>
#   <td class='result passed'></td>
# </tr>
# <tr>
#   <td class='points'>1</td>
#   <td class='test'>
#     Ingest file names are valid for 2017
#   </td>
#   <td class='result passed'></td>
# </tr>
# <tr>
#   <td class='points'>1</td>
#   <td class='test'>
#     Ingest date is valid for 2017
#   </td>
#   <td class='result passed'></td>
# </tr>
# <tr>
#   <td class='points'>1</td>
#   <td class='test'>
#     Key columns are the correct length (properly parsed)
#   </td>
#   <td class='result passed'></td>
# </tr>
#   <caption class='points'>Score: 13</caption>
# </table>

# %% [markdown]
# <h2><img src="https://files.training.databricks.com/images/105/logo_spark_tiny.png"> Exercise #2.B - Ingest Tab-Separted File</h2>
#
# **In this step you will need to:**
# 1. Use the variable **`batch_2018_path`**, and **`dbutils.fs.head`** to investigate the 2018 batch file, if needed.
# 2. Configure a **`DataFrameReader`** to ingest the tab-separated file identified by **`batch_2018_path`**
# 3. Add a new column, **`ingest_file_name`**, which is the name of the file from which the data was read from - note this should not be hard coded.
# 4. Add a new column, **`ingested_at`**, which is a timestamp of when the data was ingested as a DataFrame - note this should not be hard coded.
# 5. **Append** the corresponding **`DataFrame`** to the previously created datasets specified by **`batch_target_path`**
#
# **Additional Requirements**
# * Any **"null"** strings in the CSV file should be replaced with the SQL value **null**

# %% [markdown]
# ### Implement Exercise #2.b
#
# Implement your solution in the following cell:

# %%
# Read in the tsv file into a dataframe
df_2018 = spark.read.option("sep", '\t').option("header", True).format('csv').load(batch_2018_path)

# Replace csv "null" string with SQL value null
df_2018 = df_2018.na.replace('null', None)

# Add columns containing the source file name and the time it was ingested at
df_2018 = df_2018.withColumn("ingest_file_name", input_file_name()).withColumn("ingested_at", current_timestamp())

# Write the dataframe to delta table
df_2018.write.format("delta").mode("append").save(batch_target_path)

# %% [markdown]
# ### Reality Check #2.B
# Run the following command to ensure that you are on track:

# %%
reality_check_02_b()
# Out:
# PYTHON ERROR Invalid argument, not a string or column: 1636990796158.4683 of type <class 'float'>. For column literals, use 'lit', 'array', 'struct' or 'create_map' function.
# PYTHON ERROR Invalid argument, not a string or column: 1636990796341.9612 of type <class 'float'>. For column literals, use 'lit', 'array', 'struct' or 'create_map' function.
# PYTHON ERROR Invalid argument, not a string or column: 1636990796525.808 of type <class 'float'>. For column literals, use 'lit', 'array', 'struct' or 'create_map' function.
# PYTHON ERROR Invalid argument, not a string or column: 1636990796630.7593 of type <class 'float'>. For column literals, use 'lit', 'array', 'struct' or 'create_map' function.
# PYTHON ERROR Invalid argument, not a string or column: 1636990798836.0396 of type <class 'float'>. For column literals, use 'lit', 'array', 'struct' or 'create_map' function.
# PYTHON ERROR Invalid argument, not a string or column: 1636990838017.1326 of type <class 'float'>. For column literals, use 'lit', 'array', 'struct' or 'create_map' function.
# PYTHON ERROR Invalid argument, not a string or column: 1636990875664.1602 of type <class 'float'>. For column literals, use 'lit', 'array', 'struct' or 'create_map' function.
# PYTHON ERROR Invalid argument, not a string or column: 1636990911845.8723 of type <class 'float'>. For column literals, use 'lit', 'array', 'struct' or 'create_map' function.
# PYTHON ERROR Invalid argument, not a string or column: 1636990915276.5369 of type <class 'float'>. For column literals, use 'lit', 'array', 'struct' or 'create_map' function.
# PYTHON ERROR Invalid argument, not a string or column: 1636990917558.4377 of type <class 'float'>. For column literals, use 'lit', 'array', 'struct' or 'create_map' function.
# PYTHON ERROR Invalid argument, not a string or column: 1636990934118.8203 of type <class 'float'>. For column literals, use 'lit', 'array', 'struct' or 'create_map' function.
# PYTHON ERROR Invalid argument, not a string or column: 1636990934156.025 of type <class 'float'>. For column literals, use 'lit', 'array', 'struct' or 'create_map' function.
# <style>
#   table { text-align: left; border-collapse: collapse; margin: 1em; caption-side: bottom; font-family: Sans-Serif; font-size: 16px}
#   caption { text-align: left; padding: 5px }
#   th, td { border: 1px solid #ddd; padding: 5px }
#   th { background-color: #ddd }
#   .passed { background-color: #97d897 }
#   .failed { background-color: #e2716c }
#   .skipped { background-color: #f9d275 }
#   .results .points { display: none }
#   .results .message { display: block; font-size:smaller; color:gray }
#   .results .note { display: block; font-size:smaller; font-decoration:italics }
#   .results .passed::before  { content: "Passed" }
#   .results .failed::before  { content: "Failed" }
#   .results .skipped::before { content: "Skipped" }
#   .grade .passed  .message:empty::before { content:"Passed" }
#   .grade .failed  .message:empty::before { content:"Failed" }
#   .grade .skipped .message:empty::before { content:"Skipped" }
# </style>
# <table class='results'>
#   <tr><th class='points'>Points</th><th class='test'>Test</th><th class='result'>Result</th></tr>
# <tr>
#   <td class='points'>1</td>
#   <td class='test'>
#     Target directory exists
#   </td>
#   <td class='result passed'></td>
# </tr>
# <tr>
#   <td class='points'>1</td>
#   <td class='test'>
#     Using the Delta file format
#   </td>
#   <td class='result passed'></td>
# </tr>
# <tr>
#   <td class='points'>1</td>
#   <td class='test'>
#     Found at least one Parquet part-file
#   </td>
#   <td class='result passed'></td>
# </tr>
# <tr>
#   <td class='points'>1</td>
#   <td class='test'>
#     Schema is valid
#   </td>
#   <td class='result passed'></td>
# </tr>
# <tr>
#   <td class='points'>1</td>
#   <td class='test'>
#     Expected 784,647 records
#   </td>
#   <td class='result passed'></td>
# </tr>
# <tr>
#   <td class='points'>1</td>
#   <td class='test'>
#     No leading or trailing whitespace in column values, need to trim
#   </td>
#   <td class='result passed'></td>
# </tr>
# <tr>
#   <td class='points'>1</td>
#   <td class='test'>
#     No empty strings in column values, should be the SQL value null
#   </td>
#   <td class='result passed'></td>
# </tr>
# <tr>
#   <td class='points'>1</td>
#   <td class='test'>
#     No "null" strings for column values, should be the SQL value null
#   </td>
#   <td class='result passed'></td>
# </tr>
# <tr>
#   <td class='points'>1</td>
#   <td class='test'>
#     Ingest file names are valid for 2018
#   </td>
#   <td class='result passed'></td>
# </tr>
# <tr>
#   <td class='points'>1</td>
#   <td class='test'>
#     Ingest date is valid for 2018
#   </td>
#   <td class='result passed'></td>
# </tr>
# <tr>
#   <td class='points'>1</td>
#   <td class='test'>
#     Key columns are the correct length (properly parsed)
#   </td>
#   <td class='result passed'></td>
# </tr>
#   <caption class='points'>Score: 11</caption>
# </table>

# %% [markdown]
# <h2><img src="https://files.training.databricks.com/images/105/logo_spark_tiny.png"> Exercise #2.C - Ingest Comma-Separted File</h2>
#
# **In this step you will need to:**
# 1. Use the variable **`batch_2019_path`**, and **`dbutils.fs.head`** to investigate the 2019 batch file, if needed.
# 2. Configure a **`DataFrameReader`** to ingest the comma-separated file identified by **`batch_2019_path`**
# 3. Add a new column, **`ingest_file_name`**, which is the name of the file from which the data was read from - note this should not be hard coded.
# 4. Add a new column, **`ingested_at`**, which is a timestamp of when the data was ingested as a DataFrame - note this should not be hard coded.
# 5. **Append** the corresponding **`DataFrame`** to the previously created dataset specified by **`batch_target_path`**<br/>
#    Note: The column names in this dataset must be updated to conform to the schema defined for Exercise #2.A - there are several strategies for this:
#    * Provide a schema that alters the names upon ingestion
#    * Manually rename one column at a time
#    * Use **`fixed_width_column_defs`** programaticly rename one column at a time
#    * Use transformations found in the **`DataFrame`** class to rename all columns in one operation
#
# **Additional Requirements**
# * Any **"null"** strings in the CSV file should be replaced with the SQL value **null**<br/>

# %% [markdown]
# ### Implement Exercise #2.C
#
# Implement your solution in the following cell:

# %%
from pyspark.sql.types import StringType, StructType, StructField

# Defining schema based on 2017 and 2018 column names for import of 2019 data
defined_schema = StructType([
    StructField("submitted_at", StringType(), True),
    StructField("order_id", StringType(), True),
    StructField("customer_id", StringType(), True),
    StructField("sales_rep_id", StringType(), True),
    StructField("sales_rep_ssn", StringType(), True),
    StructField("sales_rep_first_name", StringType(), True),
    StructField("sales_rep_last_name", StringType(), True),
    StructField("sales_rep_address", StringType(), True),
    StructField("sales_rep_city", StringType(), True),
    StructField("sales_rep_state", StringType(), True),
    StructField("sales_rep_zip", StringType(), True),
    StructField("shipping_address_attention", StringType(), True),
    StructField("shipping_address_address", StringType(), True),
    StructField("shipping_address_city", StringType(), True),
    StructField("shipping_address_state", StringType(), True),
    StructField("shipping_address_zip", StringType(), True),
    StructField("product_id", StringType(), True),
    StructField("product_quantity", StringType(), True),
    StructField("product_sold_price", StringType(), True)
])

# # Read in the csv file into a dataframe
df_2019 = spark.read.option("header", True).schema(defined_schema).format('csv').load(batch_2019_path)

# # Replace csv "null" string with SQL value null
df_2019 = df_2019.na.replace('null', None)

# # Add columns containing the source file name and the time it was ingested at
df_2019 = df_2019.withColumn("ingest_file_name", input_file_name()).withColumn("ingested_at", current_timestamp())

# Write the dataframe to delta table
df_2019.write.format("delta").mode("append").save(batch_target_path)

# %% [markdown]
# ### Reality Check #2.C
# Run the following command to ensure that you are on track:

# %%
reality_check_02_c()
# Out:
# PYTHON ERROR Invalid argument, not a string or column: 1636990958776.9055 of type <class 'float'>. For column literals, use 'lit', 'array', 'struct' or 'create_map' function.
# PYTHON ERROR Invalid argument, not a string or column: 1636990958966.8657 of type <class 'float'>. For column literals, use 'lit', 'array', 'struct' or 'create_map' function.
# PYTHON ERROR Invalid argument, not a string or column: 1636990959149.929 of type <class 'float'>. For column literals, use 'lit', 'array', 'struct' or 'create_map' function.
# PYTHON ERROR Invalid argument, not a string or column: 1636990959245.3945 of type <class 'float'>. For column literals, use 'lit', 'array', 'struct' or 'create_map' function.
# PYTHON ERROR Invalid argument, not a string or column: 1636990961417.6409 of type <class 'float'>. For column literals, use 'lit', 'array', 'struct' or 'create_map' function.
# PYTHON ERROR Invalid argument, not a string or column: 1636991017013.8633 of type <class 'float'>. For column literals, use 'lit', 'array', 'struct' or 'create_map' function.
# PYTHON ERROR Invalid argument, not a string or column: 1636991067287.2698 of type <class 'float'>. For column literals, use 'lit', 'array', 'struct' or 'create_map' function.
# PYTHON ERROR Invalid argument, not a string or column: 1636991116814.672 of type <class 'float'>. For column literals, use 'lit', 'array', 'struct' or 'create_map' function.
# PYTHON ERROR Invalid argument, not a string or column: 1636991121804.6746 of type <class 'float'>. For column literals, use 'lit', 'array', 'struct' or 'create_map' function.
# PYTHON ERROR Invalid argument, not a string or column: 1636991124566.5337 of type <class 'float'>. For column literals, use 'lit', 'array', 'struct' or 'create_map' function.
# PYTHON ERROR Invalid argument, not a string or column: 1636991147224.7424 of type <class 'float'>. For column literals, use 'lit', 'array', 'struct' or 'create_map' function.
# PYTHON ERROR Invalid argument, not a string or column: 1636991147254.4355 of type <class 'float'>. For column literals, use 'lit', 'array', 'struct' or 'create_map' function.
# <style>
#   table { text-align: left; border-collapse: collapse; margin: 1em; caption-side: bottom; font-family: Sans-Serif; font-size: 16px}
#   caption { text-align: left; padding: 5px }
#   th, td { border: 1px solid #ddd; padding: 5px }
#   th { background-color: #ddd }
#   .passed { background-color: #97d897 }
#   .failed { background-color: #e2716c }
#   .skipped { background-color: #f9d275 }
#   .results .points { display: none }
#   .results .message { display: block; font-size:smaller; color:gray }
#   .results .note { display: block; font-size:smaller; font-decoration:italics }
#   .results .passed::before  { content: "Passed" }
#   .results .failed::before  { content: "Failed" }
#   .results .skipped::before { content: "Skipped" }
#   .grade .passed  .message:empty::before { content:"Passed" }
#   .grade .failed  .message:empty::before { content:"Failed" }
#   .grade .skipped .message:empty::before { content:"Skipped" }
# </style>
# <table class='results'>
#   <tr><th class='points'>Points</th><th class='test'>Test</th><th class='result'>Result</th></tr>
# <tr>
#   <td class='points'>1</td>
#   <td class='test'>
#     Target directory exists
#   </td>
#   <td class='result passed'></td>
# </tr>
# <tr>
#   <td class='points'>1</td>
#   <td class='test'>
#     Using the Delta file format
#   </td>
#   <td class='result passed'></td>
# </tr>
# <tr>
#   <td class='points'>1</td>
#   <td class='test'>
#     Found at least one Parquet part-file
#   </td>
#   <td class='result passed'></td>
# </tr>
# <tr>
#   <td class='points'>1</td>
#   <td class='test'>
#     Schema is valid
#   </td>
#   <td class='result passed'></td>
# </tr>
# <tr>
#   <td class='points'>1</td>
#   <td class='test'>
#     Expected 1,175,870 records
#   </td>
#   <td class='result passed'></td>
# </tr>
# <tr>
#   <td class='points'>1</td>
#   <td class='test'>
#     No leading or trailing whitespace in column values, need to trim
#   </td>
#   <td class='result passed'></td>
# </tr>
# <tr>
#   <td class='points'>1</td>
#   <td class='test'>
#     No empty strings in column values, should be the SQL value null
#   </td>
#   <td class='result passed'></td>
# </tr>
# <tr>
#   <td class='points'>1</td>
#   <td class='test'>
#     No "null" strings for column values, should be the SQL value null
#   </td>
#   <td class='result passed'></td>
# </tr>
# <tr>
#   <td class='points'>1</td>
#   <td class='test'>
#     Ingest file names are valid for 2019
#   </td>
#   <td class='result passed'></td>
# </tr>
# <tr>
#   <td class='points'>1</td>
#   <td class='test'>
#     Ingest date is valid for 2019
#   </td>
#   <td class='result passed'></td>
# </tr>
# <tr>
#   <td class='points'>1</td>
#   <td class='test'>
#     Key columns are the correct length (properly parsed)
#   </td>
#   <td class='result passed'></td>
# </tr>
#   <caption class='points'>Score: 11</caption>
# </table>

# %% [markdown]
# <h2><img src="https://files.training.databricks.com/images/105/logo_spark_tiny.png"> Exercise #2 - Final Check</h2>
#
# Run the following command to make sure this exercise is complete:

# %%
reality_check_02_final()
# Out:
# PYTHON ERROR Invalid argument, not a string or column: 1636991147297.8127 of type <class 'float'>. For column literals, use 'lit', 'array', 'struct' or 'create_map' function.
# PYTHON ERROR Invalid argument, not a string or column: 1636991147312.6528 of type <class 'float'>. For column literals, use 'lit', 'array', 'struct' or 'create_map' function.
# PYTHON ERROR Invalid argument, not a string or column: 1636991147326.318 of type <class 'float'>. For column literals, use 'lit', 'array', 'struct' or 'create_map' function.
# PYTHON ERROR Invalid argument, not a string or column: 1636991147506.9524 of type <class 'float'>. For column literals, use 'lit', 'array', 'struct' or 'create_map' function.
# PYTHON ERROR Invalid argument, not a string or column: 1636991147715.3125 of type <class 'float'>. For column literals, use 'lit', 'array', 'struct' or 'create_map' function.
# PYTHON ERROR Invalid argument, not a string or column: 1636991147892.5483 of type <class 'float'>. For column literals, use 'lit', 'array', 'struct' or 'create_map' function.
# PYTHON ERROR Invalid argument, not a string or column: 1636991147976.1323 of type <class 'float'>. For column literals, use 'lit', 'array', 'struct' or 'create_map' function.
# PYTHON ERROR Invalid argument, not a string or column: 1636991149085.286 of type <class 'float'>. For column literals, use 'lit', 'array', 'struct' or 'create_map' function.
# PYTHON ERROR Invalid argument, not a string or column: 1636991196113.268 of type <class 'float'>. For column literals, use 'lit', 'array', 'struct' or 'create_map' function.
# PYTHON ERROR Invalid argument, not a string or column: 1636991243956.3582 of type <class 'float'>. For column literals, use 'lit', 'array', 'struct' or 'create_map' function.
# PYTHON ERROR Invalid argument, not a string or column: 1636991291931.2036 of type <class 'float'>. For column literals, use 'lit', 'array', 'struct' or 'create_map' function.
# PYTHON ERROR Invalid argument, not a string or column: 1636991296469.0867 of type <class 'float'>. For column literals, use 'lit', 'array', 'struct' or 'create_map' function.
# PYTHON ERROR Invalid argument, not a string or column: 1636991299230.5813 of type <class 'float'>. For column literals, use 'lit', 'array', 'struct' or 'create_map' function.
# PYTHON ERROR Invalid argument, not a string or column: 1636991303830.9907 of type <class 'float'>. For column literals, use 'lit', 'array', 'struct' or 'create_map' function.
# PYTHON ERROR Invalid argument, not a string or column: 1636991306844.7122 of type <class 'float'>. For column literals, use 'lit', 'array', 'struct' or 'create_map' function.
# PYTHON ERROR Invalid argument, not a string or column: 1636991311730.5137 of type <class 'float'>. For column literals, use 'lit', 'array', 'struct' or 'create_map' function.
# PYTHON ERROR Invalid argument, not a string or column: 1636991314598.6472 of type <class 'float'>. For column literals, use 'lit', 'array', 'struct' or 'create_map' function.
# PYTHON ERROR Invalid argument, not a string or column: 1636991336897.3726 of type <class 'float'>. For column literals, use 'lit', 'array', 'struct' or 'create_map' function.
# PYTHON ERROR Invalid argument, not a string or column: 1636991336914.5737 of type <class 'float'>. For column literals, use 'lit', 'array', 'struct' or 'create_map' function.
# PYTHON ERROR Invalid argument, not a string or column: 1636991336930.4043 of type <class 'float'>. For column literals, use 'lit', 'array', 'struct' or 'create_map' function.
# <style>
#   table { text-align: left; border-collapse: collapse; margin: 1em; caption-side: bottom; font-family: Sans-Serif; font-size: 16px}
#   caption { text-align: left; padding: 5px }
#   th, td { border: 1px solid #ddd; padding: 5px }
#   th { background-color: #ddd }
#   .passed { background-color: #97d897 }
#   .failed { background-color: #e2716c }
#   .skipped { background-color: #f9d275 }
#   .results .points { display: none }
#   .results .message { display: block; font-size:smaller; color:gray }
#   .results .note { display: block; font-size:smaller; font-decoration:italics }
#   .results .passed::before  { content: "Passed" }
#   .results .failed::before  { content: "Failed" }
#   .results .skipped::before { content: "Skipped" }
#   .grade .passed  .message:empty::before { content:"Passed" }
#   .grade .failed  .message:empty::before { content:"Failed" }
#   .grade .skipped .message:empty::before { content:"Skipped" }
# </style>
# <table class='results'>
#   <tr><th class='points'>Points</th><th class='test'>Test</th><th class='result'>Result</th></tr>
# <tr>
#   <td class='points'>1</td>
#   <td class='test'>
#     Reality Check 02.A passed
#   </td>
#   <td class='result passed'></td>
# </tr>
# <tr>
#   <td class='points'>1</td>
#   <td class='test'>
#     Reality Check 02.B passed
#   </td>
#   <td class='result passed'></td>
# </tr>
# <tr>
#   <td class='points'>1</td>
#   <td class='test'>
#     Reality Check 02.C passed
#   </td>
#   <td class='result passed'></td>
# </tr>
# <tr>
#   <td class='points'>1</td>
#   <td class='test'>
#     Target directory exists
#   </td>
#   <td class='result passed'></td>
# </tr>
# <tr>
#   <td class='points'>1</td>
#   <td class='test'>
#     Using the Delta file format
#   </td>
#   <td class='result passed'></td>
# </tr>
# <tr>
#   <td class='points'>1</td>
#   <td class='test'>
#     Found at least one Parquet part-file
#   </td>
#   <td class='result passed'></td>
# </tr>
# <tr>
#   <td class='points'>1</td>
#   <td class='test'>
#     Schema is valid
#   </td>
#   <td class='result passed'></td>
# </tr>
# <tr>
#   <td class='points'>1</td>
#   <td class='test'>
#     Expected 1,175,870 records
#   </td>
#   <td class='result passed'></td>
# </tr>
# <tr>
#   <td class='points'>1</td>
#   <td class='test'>
#     No leading or trailing whitespace in column values, need to trim
#   </td>
#   <td class='result passed'></td>
# </tr>
# <tr>
#   <td class='points'>1</td>
#   <td class='test'>
#     No empty strings in column values, should be the SQL value null
#   </td>
#   <td class='result passed'></td>
# </tr>
# <tr>
#   <td class='points'>1</td>
#   <td class='test'>
#     No "null" strings for column values, should be the SQL value null
#   </td>
#   <td class='result passed'></td>
# </tr>
# <tr>
#   <td class='points'>1</td>
#   <td class='test'>
#     Ingest file names are valid for 2017
#   </td>
#   <td class='result passed'></td>
# </tr>
# <tr>
#   <td class='points'>1</td>
#   <td class='test'>
#     Ingest date is valid for 2017
#   </td>
#   <td class='result passed'></td>
# </tr>
# <tr>
#   <td class='points'>1</td>
#   <td class='test'>
#     Ingest file names are valid for 2018
#   </td>
#   <td class='result passed'></td>
# </tr>
# <tr>
#   <td class='points'>1</td>
#   <td class='test'>
#     Ingest date is valid for 2018
#   </td>
#   <td class='result passed'></td>
# </tr>
# <tr>
#   <td class='points'>1</td>
#   <td class='test'>
#     Ingest file names are valid for 2019
#   </td>
#   <td class='result passed'></td>
# </tr>
# <tr>
#   <td class='points'>1</td>
#   <td class='test'>
#     Ingest date is valid for 2019
#   </td>
#   <td class='result passed'></td>
# </tr>
# <tr>
#   <td class='points'>1</td>
#   <td class='test'>
#     Key columns are the correct length (properly parsed)
#   </td>
#   <td class='result passed'></td>
# </tr>
#   <caption class='points'>Score: 18</caption>
# </table>

# %% [markdown]
# -sandbox
# &copy; 2021 Databricks, Inc. All rights reserved.<br/>
# Apache, Apache Spark, Spark and the Spark logo are trademarks of the <a href="http://www.apache.org/">Apache Software Foundation</a>.<br/>
# <br/>
# <a href="https://databricks.com/privacy-policy">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use">Terms of Use</a> | <a href="http://help.databricks.com/">Support</a>
